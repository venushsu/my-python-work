# %%
import pandas as pd

# %%
df=pd.read_csv('./world-happiness-report-2019.csv')

# %%
# %matplotlib tk
# %matplotlib inline
import numpy as np
import  matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 導入實際數據 折線圖

# %%
df1=df[:5]

# %%
df1.plot('Country (region)',['Corruption','Freedom','Generosity','Social support'],kind = 'line')
