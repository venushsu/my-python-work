# %%
## economics market equb

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
a = [1,2,3,4,5]

# %%
plt.plot(a,[22,15,10,7,5],label='supply')
plt.plot(a,[0,3,10,15,20],label='demand')
plt.xlabel('Quantity')
plt.ylabel('Price')
plt.title("Market Equilibrium")
plt.legend()
plt.show()
