# %% [markdown]
# # 1.5 jupyter的魔術指令

# %%
# %pylab inline

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,4,5])

# %%
randn(10)
# Out:
# array([ 0.68831445, -0.72508638, -0.24289411, -0.22814204, -1.00923441,
#        -0.07748119, -0.31695471,  0.98371533,  0.01302649, -0.02469382])

# %%
plot(randn(100))

# %%
plot([-2,1,3,5,6],[3,4,7,8,9])

# %% [markdown]
# # 1.6 做筆記

# %% [markdown]
# ## 分項說明（＊字鍵）
#
# * python
# * jupyter notebook

# %% [markdown]
# ## 連結
# [政大 mooc 網] (http://moocs.nccu.edu.tw/media/17832)

# %% [markdown]
# # 1.7變數

# %%
total = 125+23+45

# %%
total
# Out:
# 193

# %%
total *30.5
# Out:
# 5886.5

# %%
底  = 3
高 =  5

# %%
面積 = (底*高)/2

# %%
面積
# Out:
# 7.5

# %% [markdown]
# # 1.8 串列 list

# %%
L = [3,4,5,6,7,8,]

# %%
plot(L)

# %%
G=[2,4,5,7,8,]

# %%
L + G
# Out:
# [3, 4, 5, 6, 7, 8, 2, 4, 5, 7, 8]

# %% [markdown]
# ### 1.8之純量加法

# %%
L
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
L*3
# Out:
# [3, 4, 5, 6, 7, 8, 3, 4, 5, 6, 7, 8, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# # 1.9 字串 Hello World

# %%
print("hello world")
# Out:
# hello world

# %%
#用引號匡起來就是字串

# %%
name = "venus"

# %%
print('hello, ' + name + "!")
# Out:
# hello, venus!

# %% [markdown]
# ### 神奇的三引號

# %%
message = '''我來示範
中間可以換行
就像這樣'''

# %%
message
# Out:
# '我來示範\n中間可以換行\n就像這樣'

# %%
print (message)
# Out:
# 我來示範
# 中間可以換行
# 就像這樣

# %% [markdown]
# # 1.10互動

# %%
a = input('a = ')
# Out:
# a = 34

# %%
a
# Out:
# '34'

# %% [markdown]
# ## 匯率換算

# %%
m = input("美金價格:")
# Out:
# 美金價格:

# %%
float(m)*30.5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7cb4ad1f993f> in <module>
# ----> 1 float(m)*30.5
#
# ValueError: could not convert string to float:

# %%
m = input("美金價格:")
twd = float(m)*30.5
print(twd)
# Out:
# 美金價格:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-874195da967d> in <module>
#       1 m = input("美金價格:")
# ----> 2 twd = float(m)*30.5
#       3 print(twd)
#
# ValueError: could not convert string to float:

# %%
m = input("美金價格:")
twd = float(m)*30.5
print("合台幣" + str(twd) + "元")
# Out:
# 美金價格:8
# 合台幣244.0元

# %% [markdown]
# ### m原本是字串，字串轉數字用float( )，數字轉字串用str( )

# %% [markdown]
# ## 拍拍機器人

# %%
message = input(">>")
print("拍拍")
# Out:
# >>好難過
# 拍拍

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-22c02bff7899> in <module>
# ----> 1 A* B
#
# TypeError: can't multiply sequence by non-int of type 'list'
